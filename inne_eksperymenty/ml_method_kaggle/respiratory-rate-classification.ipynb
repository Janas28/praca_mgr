# %% [markdown]
# # Imports

# %%
import os
import librosa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import LSTM,GRU,Dense,MaxPooling1D,Dropout
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import add,Conv1D
from tensorflow.keras.layers import Input,BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping




from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# # Data Preprocessing

# %%
os.listdir('C:/Users/u144572/self_development/machine_learning_rr_detection/Respiratory_Sound_Database/')
df_no_diagnosis = pd.read_csv('C:/Users/u144572/self_development/machine_learning_rr_detection/Respiratory_Sound_Database/demographic_info.txt', names = 
                 ['Patient number', 'Age', 'Sex' , 'Adult BMI (kg/m2)', 'Child Weight (kg)' , 'Child Height (cm)'],
                 delimiter = ' ')

diagnosis = pd.read_csv('C:/Users/u144572/self_development/machine_learning_rr_detection/Respiratory_Sound_Database/patient_diagnosis.csv', names = ['Patient number', 'Diagnosis'])

# %%
df =  df_no_diagnosis.join(diagnosis.set_index('Patient number'), on = 'Patient number', how = 'left')
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# COPD              64
# Healthy           26
# URTI              14
# Bronchiectasis     7
# Pneumonia          6
# Bronchiolitis      6
# LRTI               2
# Asthma             1
# Name: count, dtype: int64

# %%
root = 'C:/Users/u144572/self_development/machine_learning_rr_detection/Respiratory_Sound_Database/audio_and_txt_files/'

filenames = [s.split('.')[0] for s in os.listdir(path = root) if '.txt' in s]

# %% [markdown]
# ## Read Respiratory Cycle Data

# %%
def Extract_Annotation_Data(file_name, root):
    tokens = file_name.split('_')
    recording_info = pd.DataFrame(data = [tokens], columns = ['Patient number', 'Recording index', 'Chest location','Acquisition mode','Recording equipment'])
    recording_annotations = pd.read_csv(os.path.join(root, file_name + '.txt'), names = ['Start', 'End', 'Crackles', 'Wheezes'], delimiter= '\t')
    return (recording_info, recording_annotations)

# %%
i_list = []
rec_annotations = []
rec_annotations_dict = {}
for s in filenames:
    (i,a) = Extract_Annotation_Data(s, root)
    i_list.append(i)
    rec_annotations.append(a)
    rec_annotations_dict[s] = a
recording_info = pd.concat(i_list, axis = 0)
recording_info.head()

my_index = pd.Series(list(rec_annotations_dict.keys()))

# %% [markdown]
# ## Get Respiratory Cycle length and Diagnosis

# %%
res_rate_list = []
for i in range (920):
    cycle_df = pd.DataFrame( list(rec_annotations_dict.values())[i],columns=['Start', 'End' ,'cycle length'])
    cycle_df['cycle length'] = cycle_df['End']-cycle_df['Start']
    average = cycle_df[["Start","End","cycle length"]].mean(axis=0)
    df = pd.DataFrame(average).T
    res_rate_list.append(df)

# %%
res_rate_df = pd.concat(res_rate_list,ignore_index =True)
res_rate_df['filename']= my_index.values
res_rate_df['filename']= res_rate_df['filename'].str[:3]
res_rate_df.sort_values(by=['filename'])
# Out:
#         Start        End  cycle length filename
# 0    8.639333  10.300000      1.660667      101
# 1    9.365636  11.174727      1.809091      101
# 2    9.807231  11.322615      1.515385      102
# 3    8.778667  12.047833      3.269167      103
# 4    5.434450   8.077117      2.642667      104
# ..        ...        ...           ...      ...
# 915  9.980571  12.831571      2.851000      224
# 916  9.587714  11.012214      1.424500      225
# 918  8.942800  10.927100      1.984300      226
# 917  8.444400  10.438600      1.994200      226
# 919  9.648818  11.461818      1.813000      226
#
# [920 rows x 4 columns]

# %%
# Respiratory cycle = Cycle length // 60 seconds 
avg = res_rate_df.groupby('filename').mean()
avg['respiratory rate'] = 60 // avg['cycle length'] 

# Normal Respiratory Rate (12-25) cycle/min
avg['diagnosis'] = 'out of range'
step = 5
start = 10
stop = 40

categories = []
# avg['diagnosis'][(avg['respiratory rate'] > 25 )] = "High" 
for x in range(start, stop, step):
    category = f"{x} - {x+step}"
    avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
    categories.append(category)
categories.append('out of range')
avg.diagnosis
# Out:
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# C:\Users\u144572\AppData\Local\Temp\ipykernel_38484\2830007778.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['diagnosis'][((avg['respiratory rate'] >= x) & (avg['respiratory rate'] < x + step))] = category
# filename
# 101         30 - 35
# 102         35 - 40
# 103         15 - 20
# 104         25 - 30
# 105         20 - 25
#            ...
# 222         10 - 15
# 223         15 - 20
# 224         20 - 25
# 225    out of range
# 226         30 - 35
# Name: diagnosis, Length: 126, dtype: object

# %%
sns.countplot(x=avg.diagnosis, order=categories)
my_plt = plt.xticks(rotation=90)

# %% [markdown]
# ## Save Diagnosis Data

# %%
avg.diagnosis.to_csv('respiratory_rate.csv')

# %% [markdown]
# ## Data Augmentation

# %%
audio_data = 'C:/Users/u144572/self_development/machine_learning_rr_detection/Respiratory_Sound_Database/audio_and_txt_files/'

# %%
rr_diagnosis_df = pd.read_csv('respiratory_rate.csv', names=['patient_id', 'disease'],header=0)
rr_diagnosis_df.head(4)
# Out:
#    patient_id  disease
# 0         101  30 - 35
# 1         102  35 - 40
# 2         103  15 - 20
# 3         104  25 - 30

# %%
def add_noise(data,x):
    noise = np.random.randn(len(data))
    data_noise = data + x * noise
    return data_noise

def shift(data,x):
    return np.roll(data, x)

def stretch(data, rate):
    data = librosa.effects.time_stretch(data, rate)
    return data

def pitch_shift (data , rate):
    data = librosa.effects.pitch_shift(data, sr=220250, n_steps=rate)
    return data

# %%
def mfcc_feature_exteraction_rr(dir_):
    X_=[]
    y_=[]
    COPD=[]
    copd_count=0
    data = rr_diagnosis_df
    features = 50
    for soundDir in (os.listdir(dir_)):
        if soundDir[-3:]=='wav':

            label = list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0]
            
            if (label == 'Normal'):
                data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis = 0)
                X_.append(mfccs)
                y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                
            if (label != 'Normal'):
                data_x, sampling_rate = librosa.load(dir_+soundDir,res_type='kaiser_fast')
                mfccs = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=features).T,axis = 0)
                X_.append(mfccs)
                y_.append(list(data[data['patient_id']==int(soundDir[:3])]['disease'])[0])
                
                data_shift = shift(data_x,1600)
                mfccs_shift = np.mean(librosa.feature.mfcc(y=data_shift, sr=sampling_rate, n_mfcc=features).T,axis = 0)
                X_.append(mfccs_shift)
                y_.append(label)
                
                data_noise = add_noise(data_x,0.005)
                mfccs_noise = np.mean(librosa.feature.mfcc(y=data_noise, sr=sampling_rate, n_mfcc=features).T,axis = 0)
                X_.append(mfccs_noise)
                y_.append(label)
           
                
    X_data = np.array(X_)
    y_data = np.array(y_)
    
    
    
    return X_data ,y_data

# %%
res_data, res_y = mfcc_feature_exteraction_rr(audio_data)

# %%
unique, counts = np.unique(res_y, return_counts=True)
data_count = dict(zip(unique, counts))

data = data_count

courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color =['orange','green','blue','red','yellow','black'],
        width = 0.4)
 
plt.xlabel("Diseases")
plt.ylabel("Count")
plt.title("Count of each disease")
plt.show()

print (data_count)
# Out:
# {'10 - 15': 258, '15 - 20': 852, '20 - 25': 780, '25 - 30': 699, '30 - 35': 72, '35 - 40': 24, 'out of range': 75}

# %%
categories
# Out:
# ['10 - 15',
#  '15 - 20',
#  '20 - 25',
#  '25 - 30',
#  '30 - 35',
#  '35 - 40',
#  'out of range']

# %%
res_y_data_encode = res_y.reshape(2760,1)
cat_num = 7
# print(res_y_data_encode[1], res_y_data_encode[150], res_y_data_encode[75], res_y_data_encode[87], res_y_data_encode[65])
# res_y_data_encode = np.where(res_y_data_encode == '5 - 10', np.array([1,0,0,0,0,0,0,0]).reshape(1,8), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '10 - 15', np.array([1,0,0,0,0,0,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '15 - 20', np.array([0,1,0,0,0,0,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '20 - 25', np.array([0,0,1,0,0,0,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '25 - 30', np.array([0,0,0,1,0,0,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '30 - 35', np.array([0,0,0,0,1,0,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == '35 - 40', np.array([0,0,0,0,0,1,0]).reshape(1,cat_num), res_y_data_encode)
res_y_data_encode = np.where(res_y_data_encode == 'out of range', np.array([0,0,0,0,0,0,1]).reshape(1,cat_num), res_y_data_encode)
# print(res_y_data_encode[1], res_y_data_encode[150], res_y_data_encode[75], res_y_data_encode[87], res_y_data_encode[65])

res_lables = res_y_data_encode.astype('float64')

# %%
res_features = np.array(res_data)
res_lables = np.array(res_lables)

res_features.shape , res_lables.shape
# Out:
# ((2760, 50), (2760, 7))

# %% [markdown]
# ## Data Split

# %%
x_train, x_val, y_train, y_val  = train_test_split(res_features, res_lables, test_size=0.175, random_state=10)
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.075, random_state=10)


print (x_train.shape, x_val.shape, x_test.shape)
print (y_train.shape, y_val.shape, y_test.shape)
# Out:
# (2106, 50) (483, 50) (171, 50)
# (2106, 7) (483, 7) (171, 7)

# %% [markdown]
# # LSTM Model

# %%
x_train_lstm = np.expand_dims(x_train,axis=2)
x_val_lstm = np.expand_dims(x_val,axis=2)
x_test_lstm = np.expand_dims(x_test,axis=2)

# %% [markdown]
# ## Build Model

# %%
model = Sequential()

model.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(52, 1)))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(52, 1)))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())


model.add(LSTM(256, return_sequences=True))

model.add(LSTM(128))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))


model.add(Dense(7, activation='softmax'))


model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 52, 2048)       │        12,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 26, 2048)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 26, 2048)       │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 26, 1024)       │    10,486,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 13, 1024)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 13, 1024)       │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 13, 512)        │     2,621,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 7, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 7, 256)         │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,130,503 (53.90 MB)
#  Trainable params: 14,123,335 (53.88 MB)
#  Non-trainable params: 7,168 (28.00 KB)

# %%
tf.keras.utils.plot_model(model, "net.png", show_shapes=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer=optimiser,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
cb = [EarlyStopping(patience=20,monitor='val_accuracy',mode='max',restore_best_weights=True),
      ModelCheckpoint("/kaggle/working/rr_LSTM_CNN_1.keras",save_best_only=True)]

# %% [markdown]
# ## Train Model

# %%
history = model.fit(x_train_lstm, y_train, batch_size=16, epochs=40, validation_data=(x_val_lstm, y_val),callbacks = cb)
# Out:
# Epoch 1/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 35s 265ms/step - accuracy: 0.2829 - loss: 1.7672 - val_accuracy: 0.3561 - val_loss: 1.6738
# Epoch 2/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.2937 - loss: 1.7487 - val_accuracy: 0.3499 - val_loss: 1.6316
# Epoch 3/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.3174 - loss: 1.6903 - val_accuracy: 0.4224 - val_loss: 1.5570
# Epoch 4/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 250ms/step - accuracy: 0.3391 - loss: 1.6767 - val_accuracy: 0.3416 - val_loss: 1.5676
# Epoch 5/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 250ms/step - accuracy: 0.3586 - loss: 1.6132 - val_accuracy: 0.2878 - val_loss: 1.6297
# Epoch 6/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 249ms/step - accuracy: 0.3757 - loss: 1.5822 - val_accuracy: 0.3106 - val_loss: 1.6974
# Epoch 7/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.3810 - loss: 1.5486 - val_accuracy: 0.5093 - val_loss: 1.3814
# Epoch 8/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 249ms/step - accuracy: 0.4354 - loss: 1.4652 - val_accuracy: 0.4286 - val_loss: 1.4665
# Epoch 9/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 255ms/step - accuracy: 0.4635 - loss: 1.3642 - val_accuracy: 0.5424 - val_loss: 1.3170
# Epoch 10/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.5015 - loss: 1.3228 - val_accuracy: 0.4327 - val_loss: 1.3605
# Epoch 11/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 42s 316ms/step - accuracy: 0.4863 - loss: 1.3218 - val_accuracy: 0.4803 - val_loss: 1.3061
# Epoch 12/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 40s 301ms/step - accuracy: 0.5415 - loss: 1.2437 - val_accuracy: 0.4058 - val_loss: 1.4853
# Epoch 13/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 279ms/step - accuracy: 0.5306 - loss: 1.2635 - val_accuracy: 0.6335 - val_loss: 1.0111
# Epoch 14/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 36s 274ms/step - accuracy: 0.5687 - loss: 1.1536 - val_accuracy: 0.4472 - val_loss: 1.3617
# Epoch 15/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.5467 - loss: 1.1605 - val_accuracy: 0.5197 - val_loss: 1.3426
# Epoch 16/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 251ms/step - accuracy: 0.6174 - loss: 1.0492 - val_accuracy: 0.5093 - val_loss: 1.1696
# Epoch 17/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 251ms/step - accuracy: 0.6460 - loss: 0.9945 - val_accuracy: 0.5776 - val_loss: 1.0837
# Epoch 18/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.6585 - loss: 0.9449 - val_accuracy: 0.6625 - val_loss: 0.8711
# Epoch 19/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 252ms/step - accuracy: 0.6770 - loss: 0.8887 - val_accuracy: 0.6004 - val_loss: 1.0162
# Epoch 20/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 258ms/step - accuracy: 0.6960 - loss: 0.8514 - val_accuracy: 0.6832 - val_loss: 0.8203
# Epoch 21/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 251ms/step - accuracy: 0.7022 - loss: 0.8652 - val_accuracy: 0.6149 - val_loss: 1.0366
# Epoch 22/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.6973 - loss: 0.8066 - val_accuracy: 0.7516 - val_loss: 0.7555
# Epoch 23/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 257ms/step - accuracy: 0.7277 - loss: 0.7725 - val_accuracy: 0.7308 - val_loss: 0.7527
# Epoch 24/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 257ms/step - accuracy: 0.7334 - loss: 0.7478 - val_accuracy: 0.7764 - val_loss: 0.7132
# Epoch 25/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 252ms/step - accuracy: 0.7709 - loss: 0.6702 - val_accuracy: 0.6874 - val_loss: 0.8441
# Epoch 26/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 257ms/step - accuracy: 0.8079 - loss: 0.5698 - val_accuracy: 0.7805 - val_loss: 0.6455
# Epoch 27/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 257ms/step - accuracy: 0.7976 - loss: 0.5662 - val_accuracy: 0.7039 - val_loss: 1.0651
# Epoch 28/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 35s 268ms/step - accuracy: 0.7894 - loss: 0.6215 - val_accuracy: 0.6460 - val_loss: 1.1585
# Epoch 29/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 36s 275ms/step - accuracy: 0.8183 - loss: 0.5203 - val_accuracy: 0.7246 - val_loss: 0.9456
# Epoch 30/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 35s 269ms/step - accuracy: 0.7978 - loss: 0.5974 - val_accuracy: 0.6791 - val_loss: 0.9085
# Epoch 31/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 259ms/step - accuracy: 0.7922 - loss: 0.5904 - val_accuracy: 0.7971 - val_loss: 0.6182
# Epoch 32/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 35s 262ms/step - accuracy: 0.7969 - loss: 0.5857 - val_accuracy: 0.8116 - val_loss: 0.5869
# Epoch 33/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 280ms/step - accuracy: 0.8239 - loss: 0.4906 - val_accuracy: 0.8012 - val_loss: 0.7118
# Epoch 34/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.8452 - loss: 0.4333 - val_accuracy: 0.7681 - val_loss: 0.6476
# Epoch 35/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 38s 291ms/step - accuracy: 0.8405 - loss: 0.4587 - val_accuracy: 0.8344 - val_loss: 0.4584
# Epoch 36/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 37s 283ms/step - accuracy: 0.8547 - loss: 0.4353 - val_accuracy: 0.8282 - val_loss: 0.5163
# Epoch 37/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 261ms/step - accuracy: 0.8487 - loss: 0.4017 - val_accuracy: 0.8240 - val_loss: 0.5479
# Epoch 38/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 33s 251ms/step - accuracy: 0.8604 - loss: 0.3877 - val_accuracy: 0.7350 - val_loss: 0.7814
# Epoch 39/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 0.8844 - loss: 0.3484 - val_accuracy: 0.8095 - val_loss: 0.6218
# Epoch 40/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 32s 244ms/step - accuracy: 0.8708 - loss: 0.3863 - val_accuracy: 0.8530 - val_loss: 0.5793

# %% [markdown]
# ## Evaluate Model

# %%
model.evaluate(x_val_lstm, y_val)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8496 - loss: 0.5902
# [0.5792696475982666, 0.8530020713806152]

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
#   plt.plot(epochs, loss, label='training_loss')
#   plt.plot(epochs, val_loss, label='val_loss')
#   plt.title('Loss')
#   plt.xlabel('Epochs')
#   plt.legend()
#   plt.grid()


  # Plot accuracy
  plt.figure()
  plt.grid()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

plot_loss_curves(history)

# %% [markdown]
# ## Results

# %%
classes = categories

preds = model.predict(x_test_lstm)
classpreds = [ np.argmax(t) for t in preds ]
y_testclass = [np.argmax(t) for t in y_test]
cm = confusion_matrix(y_testclass, classpreds)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
ax = sns.heatmap(cm, cmap='Blues', annot=True, fmt='d', xticklabels=classes, yticklabels=classes)

plt.title('')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
print(classification_report(y_testclass, classpreds, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#      10 - 15       0.75      0.80      0.77        15
#      15 - 20       0.95      0.84      0.89        43
#      20 - 25       0.88      0.83      0.85        53
#      25 - 30       0.75      0.98      0.85        45
#      30 - 35       0.71      0.62      0.67         8
#      35 - 40       0.00      0.00      0.00         3
# out of range       1.00      0.25      0.40         4
#
#     accuracy                           0.83       171
#    macro avg       0.72      0.62      0.63       171
# weighted avg       0.83      0.83      0.82       171
# C:\Users\u144572\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\u144572\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\u144572\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Prediction

# %%
def respiratory_rate_prediction(audio_path):
    
    classes = ["Normal", "High"]
    
    #load aduio with 22050 Hz sampling rate
    data_x, sampling_rate = librosa.load(audio_path)
    
    #extract feature using mfcc (50 features)
    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=50).T,axis = 0)

    features = features.reshape(1,50)
    
    #get the prediction and the confidence 
    test_pred = model.predict(np.expand_dims(features, axis = 2))
    classpreds = classes[np.argmax(test_pred, axis=1)[0]]
    confidence = test_pred.T[test_pred.mean(axis=0).argmax()].mean()

    print (classpreds, confidence)

# %%
respiratory_rate_prediction('/kaggle/input/audio-test/74.wav')
# Out:
# High 0.99999475

# %% [markdown]
# # GRU Model

# %%
x_train_gru = np.expand_dims(x_train,axis=1)
x_val_gru = np.expand_dims(x_val,axis=1)
x_test_gru = np.expand_dims(x_test,axis=1)

y_train_gru = np.expand_dims(y_train,axis=1)
y_val_gru = np.expand_dims(y_val,axis=1)
y_test_gru = np.expand_dims(y_test,axis=1)

# %% [markdown]
# ## Build Model

# %%
Input_Sample = Input(shape=(1,50))

model_conv = Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu')(Input_Sample)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_conv = Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu')(model_conv)
model_conv = MaxPooling1D(pool_size=2, strides = 2, padding = 'same')(model_conv)
model_conv = BatchNormalization()(model_conv)

model_2_1 = GRU(32,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_2 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_2_1)

model_3 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_conv)
model_3 = GRU(128,return_sequences=True, activation='tanh',go_backwards=True)(model_3)

model_add_1 = add([model_3,model_2])

model_5 = GRU(128,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_5 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_5)

model_6 = GRU(64,return_sequences=True,activation='tanh',go_backwards=True)(model_add_1)
model_6 = GRU(32,return_sequences=True, activation='tanh',go_backwards=True)(model_6)

model_add_2 = add([model_5,model_6,model_2_1])


model_7 = Dense(32, activation=None)(model_add_2)
model_7 = LeakyReLU()(model_7)
model_7 = Dropout(0.2)(model_7)
model_7 = Dense(128, activation=None)(model_7)
model_7 = LeakyReLU()(model_7)

model_9 = Dense(64, activation=None)(model_add_2)
model_9 = LeakyReLU()(model_9)
model_9 = Dropout(0.2)(model_9)
model_9 = Dense(128, activation=None)(model_9)
model_9 = LeakyReLU()(model_9)

model_add_3 = add([model_7,model_9])

model_10 = Dense(64, activation=None)(model_add_3)
model_10 = LeakyReLU()(model_10)
model_10 = Dropout(0.5)(model_10)

model_10 = Dense(32, activation=None)(model_10)
model_10 = LeakyReLU()(model_10)
model_10 = Dropout(0.3)(model_10)

model_10 = Dense(2, activation="softmax")(model_10)

GRU_model = Model(inputs=Input_Sample, outputs = model_10)

GRU_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1, 50)]      0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1, 256)       64256       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 1, 256)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1, 256)       1024        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1, 512)       655872      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 1, 512)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 512)       2048        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 1, 64)        110976      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 1, 32)        52416       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 1, 128)       74496       gru_2[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 1, 128)       62208       gru[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1, 128)       0           gru_3[0][0]
#                                                                  gru_1[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 1, 128)       99072       add[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 1, 64)        37248       add[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 1, 32)        15552       gru_4[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 1, 32)        9408        gru_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 32)        0           gru_5[0][0]
#                                                                  gru_7[0][0]
#                                                                  gru[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 32)        1056        add_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 64)        2112        add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 1, 32)        0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 1, 64)        0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 32)        0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1, 64)        0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 128)       4224        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 128)       8320        dropout_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 1, 128)       0           dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 1, 128)       0           dense_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 128)       0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 64)        8256        add_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 1, 64)        0           dense_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1, 64)        0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 32)        2080        dropout_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 1, 32)        0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1, 32)        0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 2)         66          dropout_5[0][0]
# ==================================================================================================
# Total params: 1,210,690
# Trainable params: 1,209,154
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(GRU_model, "GRU.png", show_shapes=True)

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate = 0.0001)
GRU_model.compile(optimizer=optimiser,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
cb = [EarlyStopping(patience=20,monitor='val_accuracy',mode='max',restore_best_weights=True),
      ModelCheckpoint("/kaggle/working/rr_GRU_CNN_1.h5",save_best_only=True)]

# %% [markdown]
# ## Train Model

# %%
history = GRU_model.fit(x_train_gru, y_train_gru, batch_size=16, epochs=250, validation_data=(x_val_gru, y_val_gru),callbacks = cb )
# Out:
# Epoch 1/250
# 66/66 [==============================] - 13s 48ms/step - loss: 0.6515 - accuracy: 0.5741 - val_loss: 0.6889 - val_accuracy: 0.5496
# Epoch 2/250
#  5/66 [=>............................] - ETA: 0s - loss: 0.6278 - accuracy: 0.6250
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 66/66 [==============================] - 1s 16ms/step - loss: 0.5699 - accuracy: 0.6863 - val_loss: 0.6409 - val_accuracy: 0.7190
# Epoch 3/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.5235 - accuracy: 0.7405 - val_loss: 0.5498 - val_accuracy: 0.7851
# Epoch 4/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.5063 - accuracy: 0.7471 - val_loss: 0.4702 - val_accuracy: 0.8636
# Epoch 5/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.4824 - accuracy: 0.7576 - val_loss: 0.4320 - val_accuracy: 0.8388
# Epoch 6/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.4592 - accuracy: 0.7842 - val_loss: 0.4012 - val_accuracy: 0.8636
# Epoch 7/250
# 66/66 [==============================] - 1s 20ms/step - loss: 0.4464 - accuracy: 0.8118 - val_loss: 0.4417 - val_accuracy: 0.8140
# Epoch 8/250
# 66/66 [==============================] - 2s 23ms/step - loss: 0.4209 - accuracy: 0.8222 - val_loss: 0.3767 - val_accuracy: 0.8388
# Epoch 9/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.4056 - accuracy: 0.8165 - val_loss: 0.3590 - val_accuracy: 0.8306
# Epoch 10/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.4032 - accuracy: 0.8165 - val_loss: 0.3407 - val_accuracy: 0.8512
# Epoch 11/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.3823 - accuracy: 0.8317 - val_loss: 0.3262 - val_accuracy: 0.8636
# Epoch 12/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.3736 - accuracy: 0.8422 - val_loss: 0.3907 - val_accuracy: 0.8223
# Epoch 13/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.3620 - accuracy: 0.8441 - val_loss: 0.3660 - val_accuracy: 0.8306
# Epoch 14/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.3550 - accuracy: 0.8479 - val_loss: 0.3073 - val_accuracy: 0.8636
# Epoch 15/250
# 66/66 [==============================] - 1s 20ms/step - loss: 0.3410 - accuracy: 0.8536 - val_loss: 0.3059 - val_accuracy: 0.8802
# Epoch 16/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.3409 - accuracy: 0.8555 - val_loss: 0.3295 - val_accuracy: 0.8471
# Epoch 17/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.3163 - accuracy: 0.8669 - val_loss: 0.2810 - val_accuracy: 0.8678
# Epoch 18/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.3120 - accuracy: 0.8764 - val_loss: 0.2980 - val_accuracy: 0.8388
# Epoch 19/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.3052 - accuracy: 0.8650 - val_loss: 0.2908 - val_accuracy: 0.8719
# Epoch 20/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.3115 - accuracy: 0.8650 - val_loss: 0.3381 - val_accuracy: 0.8388
# Epoch 21/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.2841 - accuracy: 0.8802 - val_loss: 0.3266 - val_accuracy: 0.8554
# Epoch 22/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2712 - accuracy: 0.8964 - val_loss: 0.2963 - val_accuracy: 0.8719
# Epoch 23/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2613 - accuracy: 0.8869 - val_loss: 0.2753 - val_accuracy: 0.8719
# Epoch 24/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2695 - accuracy: 0.8907 - val_loss: 0.3082 - val_accuracy: 0.8678
# Epoch 25/250
# 66/66 [==============================] - 1s 20ms/step - loss: 0.2656 - accuracy: 0.8926 - val_loss: 0.2420 - val_accuracy: 0.8967
# Epoch 26/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2433 - accuracy: 0.9030 - val_loss: 0.2906 - val_accuracy: 0.8926
# Epoch 27/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.2454 - accuracy: 0.8954 - val_loss: 0.2927 - val_accuracy: 0.8926
# Epoch 28/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2459 - accuracy: 0.8859 - val_loss: 0.3106 - val_accuracy: 0.8843
# Epoch 29/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2313 - accuracy: 0.8983 - val_loss: 0.2459 - val_accuracy: 0.8926
# Epoch 30/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2064 - accuracy: 0.9154 - val_loss: 0.3896 - val_accuracy: 0.8595
# Epoch 31/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2369 - accuracy: 0.8992 - val_loss: 0.2535 - val_accuracy: 0.9050
# Epoch 32/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2237 - accuracy: 0.9049 - val_loss: 0.2267 - val_accuracy: 0.9008
# Epoch 33/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1805 - accuracy: 0.9297 - val_loss: 0.2445 - val_accuracy: 0.9091
# Epoch 34/250
# 66/66 [==============================] - 1s 22ms/step - loss: 0.1809 - accuracy: 0.9373 - val_loss: 0.3215 - val_accuracy: 0.8926
# Epoch 35/250
# 66/66 [==============================] - 1s 22ms/step - loss: 0.1917 - accuracy: 0.9173 - val_loss: 0.2541 - val_accuracy: 0.9008
# Epoch 36/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.2117 - accuracy: 0.9163 - val_loss: 0.4457 - val_accuracy: 0.8595
# Epoch 37/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1749 - accuracy: 0.9363 - val_loss: 0.3996 - val_accuracy: 0.8719
# Epoch 38/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.2123 - accuracy: 0.9097 - val_loss: 0.2377 - val_accuracy: 0.8926
# Epoch 39/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1824 - accuracy: 0.9240 - val_loss: 0.2358 - val_accuracy: 0.9132
# Epoch 40/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.1834 - accuracy: 0.9249 - val_loss: 0.3837 - val_accuracy: 0.8636
# Epoch 41/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.2029 - accuracy: 0.9211 - val_loss: 0.3900 - val_accuracy: 0.8802
# Epoch 42/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1906 - accuracy: 0.9249 - val_loss: 0.2526 - val_accuracy: 0.9215
# Epoch 43/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.1254 - accuracy: 0.9477 - val_loss: 0.2591 - val_accuracy: 0.9215
# Epoch 44/250
# 66/66 [==============================] - 1s 20ms/step - loss: 0.1755 - accuracy: 0.9354 - val_loss: 0.2612 - val_accuracy: 0.9256
# Epoch 45/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1684 - accuracy: 0.9363 - val_loss: 0.3638 - val_accuracy: 0.8760
# Epoch 46/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1811 - accuracy: 0.9221 - val_loss: 0.2312 - val_accuracy: 0.9215
# Epoch 47/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1608 - accuracy: 0.9316 - val_loss: 0.3044 - val_accuracy: 0.8967
# Epoch 48/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1192 - accuracy: 0.9525 - val_loss: 0.3255 - val_accuracy: 0.8967
# Epoch 49/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1319 - accuracy: 0.9506 - val_loss: 0.3846 - val_accuracy: 0.8636
# Epoch 50/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1413 - accuracy: 0.9430 - val_loss: 0.2151 - val_accuracy: 0.9091
# Epoch 51/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1454 - accuracy: 0.9430 - val_loss: 0.2187 - val_accuracy: 0.9256
# Epoch 52/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1247 - accuracy: 0.9468 - val_loss: 0.2245 - val_accuracy: 0.9215
# Epoch 53/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1022 - accuracy: 0.9639 - val_loss: 0.2559 - val_accuracy: 0.9050
# Epoch 54/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1480 - accuracy: 0.9449 - val_loss: 0.2235 - val_accuracy: 0.9215
# Epoch 55/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1145 - accuracy: 0.9563 - val_loss: 0.2506 - val_accuracy: 0.9132
# Epoch 56/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1105 - accuracy: 0.9582 - val_loss: 0.2942 - val_accuracy: 0.8926
# Epoch 57/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1212 - accuracy: 0.9515 - val_loss: 0.3570 - val_accuracy: 0.8636
# Epoch 58/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.1081 - accuracy: 0.9544 - val_loss: 0.4165 - val_accuracy: 0.8802
# Epoch 59/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.1081 - accuracy: 0.9648 - val_loss: 0.1907 - val_accuracy: 0.9256
# Epoch 60/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0847 - accuracy: 0.9658 - val_loss: 0.2244 - val_accuracy: 0.9256
# Epoch 61/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1441 - accuracy: 0.9477 - val_loss: 0.3968 - val_accuracy: 0.8595
# Epoch 62/250
# 66/66 [==============================] - 1s 21ms/step - loss: 0.1116 - accuracy: 0.9591 - val_loss: 0.3207 - val_accuracy: 0.8760
# Epoch 63/250
# 66/66 [==============================] - 1s 21ms/step - loss: 0.1350 - accuracy: 0.9477 - val_loss: 0.3509 - val_accuracy: 0.8760
# Epoch 64/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.1190 - accuracy: 0.9582 - val_loss: 0.1685 - val_accuracy: 0.9298
# Epoch 65/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0816 - accuracy: 0.9705 - val_loss: 0.3191 - val_accuracy: 0.9132
# Epoch 66/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1162 - accuracy: 0.9610 - val_loss: 0.1770 - val_accuracy: 0.9298
# Epoch 67/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1200 - accuracy: 0.9591 - val_loss: 0.1899 - val_accuracy: 0.9339
# Epoch 68/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0895 - accuracy: 0.9667 - val_loss: 0.3308 - val_accuracy: 0.9050
# Epoch 69/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0983 - accuracy: 0.9610 - val_loss: 0.3581 - val_accuracy: 0.8967
# Epoch 70/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0837 - accuracy: 0.9629 - val_loss: 0.2861 - val_accuracy: 0.9174
# Epoch 71/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0872 - accuracy: 0.9677 - val_loss: 0.3134 - val_accuracy: 0.8760
# Epoch 72/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0857 - accuracy: 0.9629 - val_loss: 0.2484 - val_accuracy: 0.9050
# Epoch 73/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1170 - accuracy: 0.9572 - val_loss: 0.2684 - val_accuracy: 0.9132
# Epoch 74/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0666 - accuracy: 0.9753 - val_loss: 0.2407 - val_accuracy: 0.9132
# Epoch 75/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0965 - accuracy: 0.9658 - val_loss: 0.4294 - val_accuracy: 0.8595
# Epoch 76/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1138 - accuracy: 0.9572 - val_loss: 0.1553 - val_accuracy: 0.9421
# Epoch 77/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1135 - accuracy: 0.9572 - val_loss: 0.2242 - val_accuracy: 0.9256
# Epoch 78/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1098 - accuracy: 0.9544 - val_loss: 0.3279 - val_accuracy: 0.8967
# Epoch 79/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.1042 - accuracy: 0.9601 - val_loss: 0.2794 - val_accuracy: 0.9091
# Epoch 80/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0808 - accuracy: 0.9715 - val_loss: 0.2314 - val_accuracy: 0.9256
# Epoch 81/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0623 - accuracy: 0.9734 - val_loss: 0.3832 - val_accuracy: 0.8678
# Epoch 82/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.0566 - accuracy: 0.9781 - val_loss: 0.2670 - val_accuracy: 0.9174
# Epoch 83/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.0915 - accuracy: 0.9686 - val_loss: 0.2393 - val_accuracy: 0.9091
# Epoch 84/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.0692 - accuracy: 0.9696 - val_loss: 0.3652 - val_accuracy: 0.8884
# Epoch 85/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0971 - accuracy: 0.9667 - val_loss: 0.1927 - val_accuracy: 0.9380
# Epoch 86/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0797 - accuracy: 0.9696 - val_loss: 0.1996 - val_accuracy: 0.9380
# Epoch 87/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0754 - accuracy: 0.9696 - val_loss: 0.6020 - val_accuracy: 0.8512
# Epoch 88/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0664 - accuracy: 0.9772 - val_loss: 0.2235 - val_accuracy: 0.9339
# Epoch 89/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0785 - accuracy: 0.9667 - val_loss: 0.3682 - val_accuracy: 0.9132
# Epoch 90/250
# 66/66 [==============================] - 1s 22ms/step - loss: 0.0870 - accuracy: 0.9648 - val_loss: 0.3064 - val_accuracy: 0.9050
# Epoch 91/250
# 66/66 [==============================] - 1s 18ms/step - loss: 0.1216 - accuracy: 0.9591 - val_loss: 0.4395 - val_accuracy: 0.8760
# Epoch 92/250
# 66/66 [==============================] - 1s 21ms/step - loss: 0.0952 - accuracy: 0.9591 - val_loss: 0.3911 - val_accuracy: 0.8678
# Epoch 93/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.0721 - accuracy: 0.9724 - val_loss: 0.4668 - val_accuracy: 0.8595
# Epoch 94/250
# 66/66 [==============================] - 1s 19ms/step - loss: 0.0614 - accuracy: 0.9772 - val_loss: 0.2508 - val_accuracy: 0.9256
# Epoch 95/250
# 66/66 [==============================] - 1s 16ms/step - loss: 0.0747 - accuracy: 0.9724 - val_loss: 0.2389 - val_accuracy: 0.9132
# Epoch 96/250
# 66/66 [==============================] - 1s 17ms/step - loss: 0.0731 - accuracy: 0.9696 - val_loss: 0.2290 - val_accuracy: 0.9256

# %% [markdown]
# ## Evaluate Model

# %%
GRU_model.evaluate(x_val_gru, y_val_gru)
plot_loss_curves(history)
# Out:
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.9421

# %% [markdown]
# ## Results

# %%
classes = ["Normal", "High"]

preds = GRU_model.predict(x_test_gru)
classpreds = [ np.argmax(t) for t in preds ]
y_testclass = [np.argmax(t) for t in y_test_gru]
cm = confusion_matrix(y_testclass, classpreds)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
ax = sns.heatmap(cm, cmap='Blues', annot=True, fmt='d', xticklabels=classes, yticklabels=classes)

plt.title('')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
print(classification_report(y_testclass, classpreds, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.82      0.88        50
#         High       0.79      0.94      0.86        36
#
#     accuracy                           0.87        86
#    macro avg       0.87      0.88      0.87        86
# weighted avg       0.89      0.87      0.87        86

# %% [markdown]
# ## Prediction

# %%
def respiratory_rate_prediction_gru(audio_path):
    
    classes = ["Normal", "High"]
    
    #load aduio with 22050 Hz sampling rate
    data_x, sampling_rate = librosa.load(audio_path)
    
    #extract feature using mfcc (50 features)
    features = np.mean(librosa.feature.mfcc(y=data_x, sr=sampling_rate, n_mfcc=50).T,axis = 0)

    features = features.reshape(1,50)
    
    #get the prediction and the confidence 
    test_pred = GRU_model.predict(np.expand_dims(features, axis = 1))
    classpreds = classes[np.argmax(test_pred[0], axis=1)[0]]
    confidence = test_pred.T[test_pred[0].mean(axis=0).argmax()].mean()

    print (classpreds, confidence)

# %%
respiratory_rate_prediction_gru('/kaggle/input/audio-test/74.wav')
# Out:
# High 0.99998343
